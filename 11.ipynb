# %%
# Search All Numbered PDFs for "length:" Context and Compare Numbers (2-word context, no progress bar)

# This cell will:
# - Search all PDFs in the Downloads folder with a filename format like 180535.pdf (number.pdf only).
# - For each PDF, find all occurrences of "length:" and extract the 2 words before and after.
# - Extract numbers from each match.
# - Compare the numbers in match 1 and match 2 for each PDF.
# - Print status updates for visual feedback.
# - Output a DataFrame with project number, match details, and useful summary columns.

import os
import re
import PyPDF2
import pandas as pd

# Directory containing the PDFs
pdf_dir = r"C:\Users\clint\Desktop\RA Task\Downloads"

# Regex to match files like 180535.pdf (number.pdf only)
pdf_pattern = re.compile(r"^\d+\.pdf$")

# Function to extract numbers from a string
def extract_numbers(s):
    return re.findall(r"\d+(?:\.\d+)?", s)

# Store results
results = []

# Only include files that match the number.pdf pattern
pdf_files = [f for f in os.listdir(pdf_dir) if pdf_pattern.match(f)]

print(f"Selected {len(pdf_files)} PDF files to process (number.pdf format only).\n")

for filename in pdf_files:
    print(f"\nProcessing file: {filename}")
    pdf_path = os.path.join(pdf_dir, filename)
    try:
        with open(pdf_path, "rb") as file:
            reader = PyPDF2.PdfReader(file)
            text = ""
            for page in reader.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text + " "
            words = text.split()
            matches = []
            for i, word in enumerate(words):
                if word.lower().startswith("length:"):
                    start = max(i - 2, 0)
                    end = min(i + 3, len(words))
                    context = " ".join(words[start:end])
                    matches.append(context)
            # Extract numbers from each match
            match_numbers = [extract_numbers(m) for m in matches]
            # Compare numbers in match 1 and match 2
            comparison = None
            if len(match_numbers) >= 2:
                comparison = match_numbers[0] == match_numbers[1]
            results.append({
                "filename": filename,
                "matches": matches,
                "match_numbers": match_numbers,
                "comparison": comparison
            })
            print(f"  Found {len(matches)} 'length:' matches.")
    except Exception as e:
        print(f"Error reading {filename}: {e}")

# Print results
print("\nSummary of Results:\n" + "="*40)
for res in results:
    print(f"File: {res['filename']}")
    for idx, (match, nums) in enumerate(zip(res['matches'], res['match_numbers']), 1):
        print(f"  Match {idx}: {match}")
        print(f"    Numbers: {nums}")
    if res['comparison'] is not None:
        print(f"  Match 1 and Match 2 numbers are the same: {res['comparison']}")
    print("-" * 40)

print(f"\nProcessed {len(pdf_files)} files. {sum(1 for r in results if len(r['matches']) >= 2)} files had at least two 'length:' matches.")

# Prepare data for DataFrame
rows = []
for res in results:
    project_number = res['filename'].split('.')[0]
    match_numbers = res['match_numbers']
    # Flatten matches for columns: match_1, match_2, ...
    match_cols = {}
    max_matches = max(len(match_numbers), 2)  # At least 2 columns for consistency
    for i in range(max_matches):
        col_name = f'match_{i+1}'
        match_cols[col_name] = match_numbers[i] if i < len(match_numbers) else []
    # Check if all matches are the same (if there are at least 2 matches)
    all_same = False
    if len(match_numbers) >= 2:
        all_same = all(match_numbers[0] == m for m in match_numbers[1:])
    # Add number of matches and number of numbers found in each match
    row = {
        'project_number': project_number,
        'num_matches': len(match_numbers),
        **match_cols,
        'all_matches_same': all_same,
        'comparison_1_2': (match_numbers[0] == match_numbers[1]) if len(match_numbers) >= 2 else None,
        'numbers_in_match_1': len(match_numbers[0]) if len(match_numbers) > 0 else 0,
        'numbers_in_match_2': len(match_numbers[1]) if len(match_numbers) > 1 else 0
    }
    rows.append(row)

# Create DataFrame
pdf_df = pd.DataFrame(rows)

print("\nDataFrame of extracted length numbers and comparisons:")
display(pdf_df)
# Out:
# Selected 202 PDF files to process (number.pdf format only).
#
#
# Processing file: 170561.pdf
#   Found 2 'length:' matches.
#
# Processing file: 170626.pdf
#   Found 2 'length:' matches.
#
# Processing file: 170634.pdf
#   Found 2 'length:' matches.
#
# Processing file: 174015.pdf
#   Found 2 'length:' matches.
#
# Processing file: 174016.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180003.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180004.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180006.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180012.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180014.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180020.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180024.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180025.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180028.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180029.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180031.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180043.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180045.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180050.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180051.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180055.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180058.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180064.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180066.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180067.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180068.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180071.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180073.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180085.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180088.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180090.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180092.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180095.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180101.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180102.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180103.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180105.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180108.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180110.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180112.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180113.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180114.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180115.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180116.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180119.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180122.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180130.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180132.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180137.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180139.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180140.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180141.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180147.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180149.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180153.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180154.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180156.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180164.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180165.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180166.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180167.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180170.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180172.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180174.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180175.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180179.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180187.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180189.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180192.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180195.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180197.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180206.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180210.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180211.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180217.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180222.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180223.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180227.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180228.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180229.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180230.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180231.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180232.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180233.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180237.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180238.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180246.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180249.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180250.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180256.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180257.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180259.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180260.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180262.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180265.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180269.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180270.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180272.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180282.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180289.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180291.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180292.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180295.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180298.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180302.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180312.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180318.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180319.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180325.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180326.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180329.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180330.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180331.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180345.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180355.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180364.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180367.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180385.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180386.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180391.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180394.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180398.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180399.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180400.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180401.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180403.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180406.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180411.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180413.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180420.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180421.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180422.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180424.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180426.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180427.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180431.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180432.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180433.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180435.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180436.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180437.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180438.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180439.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180442.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180448.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180449.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180452.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180455.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180461.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180471.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180475.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180477.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180479.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180481.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180485.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180489.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180490.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180491.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180495.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180501.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180506.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180508.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180509.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180510.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180511.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180520.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180521.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180522.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180525.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180530.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180533.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180535.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180536.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180542.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180547.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180548.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180549.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180551.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180555.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180556.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180557.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180560.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180568.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180569.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180570.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180574.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180576.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180577.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180583.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180584.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180585.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180589.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180592.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180600.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180607.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180609.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180610.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180611.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180621.pdf
#   Found 2 'length:' matches.
#
# Processing file: 180622.pdf
#   Found 2 'length:' matches.
#
# Processing file: 184002.pdf
#   Found 2 'length:' matches.
#
# Processing file: 187023.pdf
#   Found 2 'length:' matches.
#
# Summary of Results:
# ========================================
# File: 170561.pdf
#   Match 1: Contract Project Length: 10.15 Miles
#     Numbers: ['10.15']
#   Match 2: Miles Work Length: 10.15 Miles
#     Numbers: ['10.15']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 170626.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 170634.pdf
#   Match 1: Contract Project Length: 13.93 Miles
#     Numbers: ['13.93']
#   Match 2: Miles Work Length: 13.93 Miles
#     Numbers: ['13.93']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 174015.pdf
#   Match 1: Contract Project Length: 5.45 Miles
#     Numbers: ['5.45']
#   Match 2: Miles Work Length: 5.45 Miles
#     Numbers: ['5.45']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 174016.pdf
#   Match 1: Contract Project Length: 1.22 MI
#     Numbers: ['1.22']
#   Match 2: Miles Work Length: 1.22 MI
#     Numbers: ['1.22']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180003.pdf
#   Match 1: Contract Project Length: 9.19 Miles
#     Numbers: ['9.19']
#   Match 2: Miles Work Length: 9.13 Miles
#     Numbers: ['9.13']
#   Match 1 and Match 2 numbers are the same: False
# ----------------------------------------
# File: 180004.pdf
#   Match 1: Contract Project Length: 1.76 Miles
#     Numbers: ['1.76']
#   Match 2: Miles Work Length: 1.76 Miles
#     Numbers: ['1.76']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180006.pdf
#   Match 1: Contract Project Length: 0.5 Miles
#     Numbers: ['0.5']
#   Match 2: Miles Work Length: 0.5 Miles
#     Numbers: ['0.5']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180012.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180014.pdf
#   Match 1: Contract Project Length: 4.45 MI
#     Numbers: ['4.45']
#   Match 2: Miles Work Length: 4.45 MI
#     Numbers: ['4.45']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180020.pdf
#   Match 1: Contract Project Length: 1.23 Miles
#     Numbers: ['1.23']
#   Match 2: Miles Work Length: 1.23 Miles
#     Numbers: ['1.23']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180024.pdf
#   Match 1: Contract Project Length: 8.14 Miles
#     Numbers: ['8.14']
#   Match 2: Miles Work Length: 8.14 Miles
#     Numbers: ['8.14']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180025.pdf
#   Match 1: Contract Project Length: 8.87 Miles
#     Numbers: ['8.87']
#   Match 2: Miles Work Length: 8.87 Miles
#     Numbers: ['8.87']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180028.pdf
#   Match 1: Contract Project Length: 1.53 Miles
#     Numbers: ['1.53']
#   Match 2: Miles Work Length: 1.53 Miles
#     Numbers: ['1.53']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180029.pdf
#   Match 1: Contract Project Length: 7.65 Miles
#     Numbers: ['7.65']
#   Match 2: Miles Work Length: 7.65 Miles
#     Numbers: ['7.65']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180031.pdf
#   Match 1: Contract Project Length: 4.60 Miles
#     Numbers: ['4.60']
#   Match 2: Miles Work Length: 4.60 Miles
#     Numbers: ['4.60']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180043.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180045.pdf
#   Match 1: Contract Project Length: 11.51 Miles
#     Numbers: ['11.51']
#   Match 2: Miles Work Length: 11.51 Miles
#     Numbers: ['11.51']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180050.pdf
#   Match 1: Contract Project Length: 2.27 Miles
#     Numbers: ['2.27']
#   Match 2: Miles Work Length: 2.27 Miles
#     Numbers: ['2.27']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180051.pdf
#   Match 1: Contract Project Length: 0.58 Miles
#     Numbers: ['0.58']
#   Match 2: Miles Work Length: 0.58 Miles
#     Numbers: ['0.58']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180055.pdf
#   Match 1: Contract Project Length: 1.82 Miles
#     Numbers: ['1.82']
#   Match 2: Miles Work Length: 1.82 Miles
#     Numbers: ['1.82']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180058.pdf
#   Match 1: Contract Project Length: 5.04 Miles
#     Numbers: ['5.04']
#   Match 2: Miles Work Length: 5.04 Miles
#     Numbers: ['5.04']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180064.pdf
#   Match 1: Contract Project Length: 9.68 Miles
#     Numbers: ['9.68']
#   Match 2: Miles Work Length: 9.68 Miles
#     Numbers: ['9.68']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180066.pdf
#   Match 1: Contract Project Length: 13.21 Miles
#     Numbers: ['13.21']
#   Match 2: Miles Work Length: 13.21 Miles
#     Numbers: ['13.21']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180067.pdf
#   Match 1: Contract Project Length: 3.61 Miles
#     Numbers: ['3.61']
#   Match 2: Miles Work Length: 3.61 Miles
#     Numbers: ['3.61']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180068.pdf
#   Match 1: Contract Project Length: 16.27 Miles
#     Numbers: ['16.27']
#   Match 2: Miles Work Length: 16.27 Miles
#     Numbers: ['16.27']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180071.pdf
#   Match 1: Contract Project Length: 23.68 Miles
#     Numbers: ['23.68']
#   Match 2: Miles Work Length: 23.68 Miles
#     Numbers: ['23.68']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180073.pdf
#   Match 1: Contract Project Length: 1.74 Miles
#     Numbers: ['1.74']
#   Match 2: Miles Work Length: 1.74 Miles
#     Numbers: ['1.74']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180085.pdf
#   Match 1: Contract Project Length: 3.11 MI
#     Numbers: ['3.11']
#   Match 2: Miles Work Length: 3.11 MI
#     Numbers: ['3.11']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180088.pdf
#   Match 1: Contract Project Length: 7.12 Miles
#     Numbers: ['7.12']
#   Match 2: Miles Work Length: 7.12 Miles
#     Numbers: ['7.12']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180090.pdf
#   Match 1: Contract Project Length: 8.85 Miles
#     Numbers: ['8.85']
#   Match 2: Miles Work Length: 8.76 Miles
#     Numbers: ['8.76']
#   Match 1 and Match 2 numbers are the same: False
# ----------------------------------------
# File: 180092.pdf
#   Match 1: Contract Project Length: 3.44 Miles
#     Numbers: ['3.44']
#   Match 2: Miles Work Length: 3.44 Miles
#     Numbers: ['3.44']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180095.pdf
#   Match 1: Contract Project Length: 14.49 MI
#     Numbers: ['14.49']
#   Match 2: Miles Work Length: 14.49 MI
#     Numbers: ['14.49']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180101.pdf
#   Match 1: Contract Project Length: N/A Miles
#     Numbers: []
#   Match 2: Miles Work Length: N/A Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180102.pdf
#   Match 1: Contract Project Length: 6.54 Miles
#     Numbers: ['6.54']
#   Match 2: Miles Work Length: 6.54 Miles
#     Numbers: ['6.54']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180103.pdf
#   Match 1: Contract Project Length: 5.82 Miles
#     Numbers: ['5.82']
#   Match 2: Miles Work Length: 5.82 Miles
#     Numbers: ['5.82']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180105.pdf
#   Match 1: Contract Project Length: 1.4 Miles
#     Numbers: ['1.4']
#   Match 2: Miles Work Length: 1.4 Miles
#     Numbers: ['1.4']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180108.pdf
#   Match 1: Contract Project Length: 2.27 Miles
#     Numbers: ['2.27']
#   Match 2: Miles Work Length: 2.27 Miles
#     Numbers: ['2.27']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180110.pdf
#   Match 1: Contract Project Length: 9.67 Miles
#     Numbers: ['9.67']
#   Match 2: Miles Work Length: 9.67 Miles
#     Numbers: ['9.67']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180112.pdf
#   Match 1: Contract Project Length: 8.42 Miles
#     Numbers: ['8.42']
#   Match 2: Miles Work Length: 8.42 Miles
#     Numbers: ['8.42']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180113.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180114.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180115.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180116.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180119.pdf
#   Match 1: Contract Project Length: 5.40 MI
#     Numbers: ['5.40']
#   Match 2: Miles Work Length: 5.40 MI
#     Numbers: ['5.40']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180122.pdf
#   Match 1: Contract Project Length: 3.2 Miles
#     Numbers: ['3.2']
#   Match 2: Miles Work Length: 3.2 Miles
#     Numbers: ['3.2']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180130.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180132.pdf
#   Match 1: Contract Project Length: 19.07 Miles
#     Numbers: ['19.07']
#   Match 2: Miles Work Length: 19.07 Miles
#     Numbers: ['19.07']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180137.pdf
#   Match 1: Contract Project Length: 5.71 Miles
#     Numbers: ['5.71']
#   Match 2: Miles Work Length: 5.71 Miles
#     Numbers: ['5.71']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180139.pdf
#   Match 1: Contract Project Length: 4.56 Miles
#     Numbers: ['4.56']
#   Match 2: Miles Work Length: 4.18 Miles
#     Numbers: ['4.18']
#   Match 1 and Match 2 numbers are the same: False
# ----------------------------------------
# File: 180140.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180141.pdf
#   Match 1: Contract Project Length: 3.47 MI
#     Numbers: ['3.47']
#   Match 2: Miles Work Length: 3.47 MI
#     Numbers: ['3.47']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180147.pdf
#   Match 1: Contract Project Length: 0.40 MI
#     Numbers: ['0.40']
#   Match 2: Miles Work Length: 0.40 MI
#     Numbers: ['0.40']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180149.pdf
#   Match 1: Contract Project Length: 9.57 Miles
#     Numbers: ['9.57']
#   Match 2: Miles Work Length: 9.57 Miles
#     Numbers: ['9.57']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180153.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180154.pdf
#   Match 1: Contract Project Length: 2.85 Miles
#     Numbers: ['2.85']
#   Match 2: Miles Work Length: 2.85 Miles
#     Numbers: ['2.85']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180156.pdf
#   Match 1: Contract Project Length: 12.1 Miles
#     Numbers: ['12.1']
#   Match 2: Miles Work Length: 12.1 Miles
#     Numbers: ['12.1']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180164.pdf
#   Match 1: Contract Project Length: 2.82 Miles
#     Numbers: ['2.82']
#   Match 2: Miles Work Length: 2.82 Miles
#     Numbers: ['2.82']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180165.pdf
#   Match 1: Contract Project Length: 9.72 Miles
#     Numbers: ['9.72']
#   Match 2: Miles Work Length: 9.72 Miles
#     Numbers: ['9.72']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180166.pdf
#   Match 1: Contract Project Length: 6.25 Miles
#     Numbers: ['6.25']
#   Match 2: Miles Work Length: 6.25 Miles
#     Numbers: ['6.25']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180167.pdf
#   Match 1: Contract Project Length: 7.56 Miles
#     Numbers: ['7.56']
#   Match 2: Miles Work Length: 7.56 Miles
#     Numbers: ['7.56']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180170.pdf
#   Match 1: Contract Project Length: 5 Miles
#     Numbers: ['5']
#   Match 2: Miles Work Length: 5 Miles
#     Numbers: ['5']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180172.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180174.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180175.pdf
#   Match 1: Contract Project Length: 20.57 Miles
#     Numbers: ['20.57']
#   Match 2: Miles Work Length: 20.57 Miles
#     Numbers: ['20.57']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180179.pdf
#   Match 1: Contract Project Length: 10.57 Miles
#     Numbers: ['10.57']
#   Match 2: Miles Work Length: 10.57 Miles
#     Numbers: ['10.57']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180187.pdf
#   Match 1: Contract Project Length: 0.07 MI
#     Numbers: ['0.07']
#   Match 2: Miles Work Length: 0.07 MI
#     Numbers: ['0.07']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180189.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180192.pdf
#   Match 1: Contract Project Length: 8.22 Miles
#     Numbers: ['8.22']
#   Match 2: Miles Work Length: 8.22 Miles
#     Numbers: ['8.22']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180195.pdf
#   Match 1: Contract Project Length: 7.54 Miles
#     Numbers: ['7.54']
#   Match 2: Miles Work Length: 7.54 Miles
#     Numbers: ['7.54']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180197.pdf
#   Match 1: Contract Project Length: 2.9 Miles
#     Numbers: ['2.9']
#   Match 2: Miles Work Length: 2.9 Miles
#     Numbers: ['2.9']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180206.pdf
#   Match 1: Contract Project Length: 4.09 Miles
#     Numbers: ['4.09']
#   Match 2: Miles Work Length: 4.09 Miles
#     Numbers: ['4.09']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180210.pdf
#   Match 1: Contract Project Length: 0.55 Miles
#     Numbers: ['0.55']
#   Match 2: Miles Work Length: 0.55 Miles
#     Numbers: ['0.55']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180211.pdf
#   Match 1: Contract Project Length: 4.06 MI
#     Numbers: ['4.06']
#   Match 2: Miles Work Length: 4.06 MI
#     Numbers: ['4.06']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180217.pdf
#   Match 1: Contract Project Length: 8.06 Miles
#     Numbers: ['8.06']
#   Match 2: Miles Work Length: 8.06 Miles
#     Numbers: ['8.06']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180222.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180223.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180227.pdf
#   Match 1: Contract Project Length: 4.675 Miles
#     Numbers: ['4.675']
#   Match 2: Miles Work Length: 4.675 Miles
#     Numbers: ['4.675']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180228.pdf
#   Match 1: Contract Project Length: 6.18 Miles
#     Numbers: ['6.18']
#   Match 2: Miles Work Length: 6.18 Miles
#     Numbers: ['6.18']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180229.pdf
#   Match 1: Contract Project Length: 2.26 Miles
#     Numbers: ['2.26']
#   Match 2: Miles Work Length: 2.26 Miles
#     Numbers: ['2.26']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180230.pdf
#   Match 1: Contract Project Length: 4.27 Miles
#     Numbers: ['4.27']
#   Match 2: Miles Work Length: 4.27 Miles
#     Numbers: ['4.27']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180231.pdf
#   Match 1: Contract Project Length: 10.94 Miles
#     Numbers: ['10.94']
#   Match 2: Miles Work Length: 10.94 Miles
#     Numbers: ['10.94']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180232.pdf
#   Match 1: Contract Project Length: 1.19 mi
#     Numbers: ['1.19']
#   Match 2: Miles Work Length: 1.20 mi
#     Numbers: ['1.20']
#   Match 1 and Match 2 numbers are the same: False
# ----------------------------------------
# File: 180233.pdf
#   Match 1: Contract Project Length: 9.00 Miles
#     Numbers: ['9.00']
#   Match 2: Miles Work Length: 9.00 Miles
#     Numbers: ['9.00']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180237.pdf
#   Match 1: Contract Project Length: 15.72 Miles
#     Numbers: ['15.72']
#   Match 2: Miles Work Length: 15.72 Miles
#     Numbers: ['15.72']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180238.pdf
#   Match 1: Contract Project Length: 1.36 Miles
#     Numbers: ['1.36']
#   Match 2: Miles Work Length: 1.36 Miles
#     Numbers: ['1.36']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180246.pdf
#   Match 1: Contract Project Length: 10.28 Miles
#     Numbers: ['10.28']
#   Match 2: Miles Work Length: 10.28 Miles
#     Numbers: ['10.28']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180249.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180250.pdf
#   Match 1: Contract Project Length: 1.55 Miles
#     Numbers: ['1.55']
#   Match 2: Miles Work Length: 1.55 Miles
#     Numbers: ['1.55']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180256.pdf
#   Match 1: Contract Project Length: 3.00 Miles
#     Numbers: ['3.00']
#   Match 2: Miles Work Length: 3.00 Miles
#     Numbers: ['3.00']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180257.pdf
#   Match 1: Contract Project Length: 6.96 Miles
#     Numbers: ['6.96']
#   Match 2: Miles Work Length: 6.96 Miles
#     Numbers: ['6.96']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180259.pdf
#   Match 1: Contract Project Length: 15.6 Miles
#     Numbers: ['15.6']
#   Match 2: Miles Work Length: 15.6 Miles
#     Numbers: ['15.6']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180260.pdf
#   Match 1: Contract Project Length: 1.09 Miles
#     Numbers: ['1.09']
#   Match 2: Miles Work Length: 1.09 Miles
#     Numbers: ['1.09']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180262.pdf
#   Match 1: Contract Project Length: 1.57 Miles
#     Numbers: ['1.57']
#   Match 2: Miles Work Length: 1.57 Miles
#     Numbers: ['1.57']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180265.pdf
#   Match 1: Contract Project Length: 3.24 MI
#     Numbers: ['3.24']
#   Match 2: Miles Work Length: 3.24 MI
#     Numbers: ['3.24']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180269.pdf
#   Match 1: Contract Project Length: 7.54 Miles
#     Numbers: ['7.54']
#   Match 2: Miles Work Length: 7.54 Miles
#     Numbers: ['7.54']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180270.pdf
#   Match 1: Contract Project Length: 2.00 Miles
#     Numbers: ['2.00']
#   Match 2: Miles Work Length: 2.00 Miles
#     Numbers: ['2.00']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180272.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180282.pdf
#   Match 1: Contract Project Length: 1.11 Miles
#     Numbers: ['1.11']
#   Match 2: Miles Work Length: 1.11 Miles
#     Numbers: ['1.11']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180289.pdf
#   Match 1: Contract Project Length: 7.94 Miles
#     Numbers: ['7.94']
#   Match 2: Miles Work Length: 7.94 Miles
#     Numbers: ['7.94']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180291.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180292.pdf
#   Match 1: Contract Project Length: 2.44 Miles
#     Numbers: ['2.44']
#   Match 2: Miles Work Length: 2.44 Miles
#     Numbers: ['2.44']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180295.pdf
#   Match 1: Contract Project Length: 0.91 Miles
#     Numbers: ['0.91']
#   Match 2: Miles Work Length: 0.91 Miles
#     Numbers: ['0.91']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180298.pdf
#   Match 1: Contract Project Length: 13.64 Miles
#     Numbers: ['13.64']
#   Match 2: Miles Work Length: 13.64 Miles
#     Numbers: ['13.64']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180302.pdf
#   Match 1: Contract Project Length: 11.77 Miles
#     Numbers: ['11.77']
#   Match 2: Miles Work Length: 11.77 Miles
#     Numbers: ['11.77']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180312.pdf
#   Match 1: Contract Project Length: na Miles
#     Numbers: []
#   Match 2: Miles Work Length: na Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180318.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180319.pdf
#   Match 1: Contract Project Length: na Miles
#     Numbers: []
#   Match 2: Miles Work Length: na Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180325.pdf
#   Match 1: Contract Project Length: 2.65 Miles
#     Numbers: ['2.65']
#   Match 2: Miles Work Length: 2.65 Miles
#     Numbers: ['2.65']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180326.pdf
#   Match 1: Contract Project Length: 6.49 MI
#     Numbers: ['6.49']
#   Match 2: Miles Work Length: 6.49 MI
#     Numbers: ['6.49']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180329.pdf
#   Match 1: Contract Project Length: 6.08 mi
#     Numbers: ['6.08']
#   Match 2: Miles Work Length: 6.08 mi
#     Numbers: ['6.08']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180330.pdf
#   Match 1: Contract Project Length: 6.55 Miles
#     Numbers: ['6.55']
#   Match 2: Miles Work Length: 6.55 Miles
#     Numbers: ['6.55']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180331.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180345.pdf
#   Match 1: Contract Project Length: 7.15 Miles
#     Numbers: ['7.15']
#   Match 2: Miles Work Length: 7.15 Miles
#     Numbers: ['7.15']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180355.pdf
#   Match 1: Contract Project Length: 8.76 Miles
#     Numbers: ['8.76']
#   Match 2: Miles Work Length: 8.76 Miles
#     Numbers: ['8.76']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180364.pdf
#   Match 1: Contract Project Length: 14.26 Miles
#     Numbers: ['14.26']
#   Match 2: Miles Work Length: 14.26 Miles
#     Numbers: ['14.26']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180367.pdf
#   Match 1: Contract Project Length: 11.2 Miles
#     Numbers: ['11.2']
#   Match 2: Miles Work Length: 11.2 Miles
#     Numbers: ['11.2']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180385.pdf
#   Match 1: Contract Project Length: 2.85 Miles
#     Numbers: ['2.85']
#   Match 2: Miles Work Length: 2.76 Miles
#     Numbers: ['2.76']
#   Match 1 and Match 2 numbers are the same: False
# ----------------------------------------
# File: 180386.pdf
#   Match 1: Contract Project Length: 3.43 Miles
#     Numbers: ['3.43']
#   Match 2: Miles Work Length: 3.43 Miles
#     Numbers: ['3.43']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180391.pdf
#   Match 1: Contract Project Length: 4.19 Miles
#     Numbers: ['4.19']
#   Match 2: Miles Work Length: 4.19 Miles
#     Numbers: ['4.19']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180394.pdf
#   Match 1: Contract Project Length: 5.84 MI
#     Numbers: ['5.84']
#   Match 2: Miles Work Length: 5.84 MI
#     Numbers: ['5.84']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180398.pdf
#   Match 1: Contract Project Length: 18.57 Miles
#     Numbers: ['18.57']
#   Match 2: Miles Work Length: 18.57 Miles
#     Numbers: ['18.57']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180399.pdf
#   Match 1: Contract Project Length: 9.51 Miles
#     Numbers: ['9.51']
#   Match 2: Miles Work Length: 9.51 Miles
#     Numbers: ['9.51']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180400.pdf
#   Match 1: Contract Project Length: 2.56 Miles
#     Numbers: ['2.56']
#   Match 2: Miles Work Length: 2.56 Miles
#     Numbers: ['2.56']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180401.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180403.pdf
#   Match 1: Contract Project Length: 13.52 MI
#     Numbers: ['13.52']
#   Match 2: Miles Work Length: 13.52 MI
#     Numbers: ['13.52']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180406.pdf
#   Match 1: Contract Project Length: 5.86 Miles
#     Numbers: ['5.86']
#   Match 2: Miles Work Length: 5.86 Miles
#     Numbers: ['5.86']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180411.pdf
#   Match 1: Contract Project Length: 17.62 Miles
#     Numbers: ['17.62']
#   Match 2: Miles Work Length: 17.62 Miles
#     Numbers: ['17.62']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180413.pdf
#   Match 1: Contract Project Length: 5.90 Miles
#     Numbers: ['5.90']
#   Match 2: Miles Work Length: 5.90 Miles
#     Numbers: ['5.90']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180420.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180421.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180422.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180424.pdf
#   Match 1: Contract Project Length: 5.27 Miles
#     Numbers: ['5.27']
#   Match 2: Miles Work Length: 5.27 Miles
#     Numbers: ['5.27']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180426.pdf
#   Match 1: Contract Project Length: 16.06 Miles
#     Numbers: ['16.06']
#   Match 2: Miles Work Length: 16.06 Miles
#     Numbers: ['16.06']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180427.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180431.pdf
#   Match 1: Contract Project Length: 8.07 Miles
#     Numbers: ['8.07']
#   Match 2: Miles Work Length: 8.07 Miles
#     Numbers: ['8.07']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180432.pdf
#   Match 1: Contract Project Length: 10.54 MI
#     Numbers: ['10.54']
#   Match 2: Miles Work Length: 10.54 MI
#     Numbers: ['10.54']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180433.pdf
#   Match 1: Contract Project Length: 5.79 MI
#     Numbers: ['5.79']
#   Match 2: Miles Work Length: 5.79 MI
#     Numbers: ['5.79']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180435.pdf
#   Match 1: Contract Project Length: 3.54 Miles
#     Numbers: ['3.54']
#   Match 2: Miles Work Length: 3.54 Miles
#     Numbers: ['3.54']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180436.pdf
#   Match 1: Contract Project Length: 0.56 Miles
#     Numbers: ['0.56']
#   Match 2: Miles Work Length: 0.56 Miles
#     Numbers: ['0.56']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180437.pdf
#   Match 1: Contract Project Length: 1.88 Miles
#     Numbers: ['1.88']
#   Match 2: Miles Work Length: 1.88 Miles
#     Numbers: ['1.88']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180438.pdf
#   Match 1: Contract Project Length: 10.64 Miles
#     Numbers: ['10.64']
#   Match 2: Miles Work Length: 10.64 Miles
#     Numbers: ['10.64']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180439.pdf
#   Match 1: Contract Project Length: 5.65 Miles
#     Numbers: ['5.65']
#   Match 2: Miles Work Length: 5.65 Miles
#     Numbers: ['5.65']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180442.pdf
#   Match 1: Contract Project Length: 12.37 Miles
#     Numbers: ['12.37']
#   Match 2: Miles Work Length: 12.37 Miles
#     Numbers: ['12.37']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180448.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180449.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180452.pdf
#   Match 1: Contract Project Length: 27.46 Miles
#     Numbers: ['27.46']
#   Match 2: Miles Work Length: 27.46 Miles
#     Numbers: ['27.46']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180455.pdf
#   Match 1: Contract Project Length: 13.99 Miles
#     Numbers: ['13.99']
#   Match 2: Miles Work Length: 13.99 Miles
#     Numbers: ['13.99']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180461.pdf
#   Match 1: Contract Project Length: 5.54 MI
#     Numbers: ['5.54']
#   Match 2: Miles Work Length: 5.54 MI
#     Numbers: ['5.54']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180471.pdf
#   Match 1: Contract Project Length: 3.64 Miles
#     Numbers: ['3.64']
#   Match 2: Miles Work Length: 3.64 Miles
#     Numbers: ['3.64']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180475.pdf
#   Match 1: Contract Project Length: 18.97 Miles
#     Numbers: ['18.97']
#   Match 2: Miles Work Length: 18.92 Miles
#     Numbers: ['18.92']
#   Match 1 and Match 2 numbers are the same: False
# ----------------------------------------
# File: 180477.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180479.pdf
#   Match 1: Contract Project Length: 8.65 Miles
#     Numbers: ['8.65']
#   Match 2: Miles Work Length: 8.65 Miles
#     Numbers: ['8.65']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180481.pdf
#   Match 1: Contract Project Length: 9.83 MI
#     Numbers: ['9.83']
#   Match 2: Miles Work Length: 9.83 MI
#     Numbers: ['9.83']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180485.pdf
#   Match 1: Contract Project Length: 47.25 Miles
#     Numbers: ['47.25']
#   Match 2: Miles Work Length: 47.25 Miles
#     Numbers: ['47.25']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180489.pdf
#   Match 1: Contract Project Length: 2.71 MI
#     Numbers: ['2.71']
#   Match 2: Miles Work Length: 2.71 MI
#     Numbers: ['2.71']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180490.pdf
#   Match 1: Contract Project Length: 1.18 Miles
#     Numbers: ['1.18']
#   Match 2: Miles Work Length: 1.25 Miles
#     Numbers: ['1.25']
#   Match 1 and Match 2 numbers are the same: False
# ----------------------------------------
# File: 180491.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180495.pdf
#   Match 1: Contract Project Length: 7.21 MI
#     Numbers: ['7.21']
#   Match 2: Miles Work Length: 7.21 MI
#     Numbers: ['7.21']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180501.pdf
#   Match 1: Contract Project Length: 9.94 Miles
#     Numbers: ['9.94']
#   Match 2: Miles Work Length: 9.94 Miles
#     Numbers: ['9.94']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180506.pdf
#   Match 1: Contract Project Length: 6.37 Miles
#     Numbers: ['6.37']
#   Match 2: Miles Work Length: 6.37 Miles
#     Numbers: ['6.37']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180508.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180509.pdf
#   Match 1: Contract Project Length: 12.47 Miles
#     Numbers: ['12.47']
#   Match 2: Miles Work Length: 12.31 Miles
#     Numbers: ['12.31']
#   Match 1 and Match 2 numbers are the same: False
# ----------------------------------------
# File: 180510.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180511.pdf
#   Match 1: Contract Project Length: 6.25 Miles
#     Numbers: ['6.25']
#   Match 2: Miles Work Length: 6.25 Miles
#     Numbers: ['6.25']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180520.pdf
#   Match 1: Contract Project Length: 19.40 MI
#     Numbers: ['19.40']
#   Match 2: Miles Work Length: 19.20 MI
#     Numbers: ['19.20']
#   Match 1 and Match 2 numbers are the same: False
# ----------------------------------------
# File: 180521.pdf
#   Match 1: Contract Project Length: 17.75 Miles
#     Numbers: ['17.75']
#   Match 2: Miles Work Length: 17.75 Miles
#     Numbers: ['17.75']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180522.pdf
#   Match 1: Contract Project Length: 16.98 MI
#     Numbers: ['16.98']
#   Match 2: Miles Work Length: 12.27 MI
#     Numbers: ['12.27']
#   Match 1 and Match 2 numbers are the same: False
# ----------------------------------------
# File: 180525.pdf
#   Match 1: Contract Project Length: 7.49 MI
#     Numbers: ['7.49']
#   Match 2: Miles Work Length: 7.49 MI
#     Numbers: ['7.49']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180530.pdf
#   Match 1: Contract Project Length: 4.39 Miles
#     Numbers: ['4.39']
#   Match 2: Miles Work Length: 4.39 Miles
#     Numbers: ['4.39']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180533.pdf
#   Match 1: Contract Project Length: 7.02 Miles
#     Numbers: ['7.02']
#   Match 2: Miles Work Length: 7.02 Miles
#     Numbers: ['7.02']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180535.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180536.pdf
#   Match 1: Contract Project Length: 19.21 Miles
#     Numbers: ['19.21']
#   Match 2: Miles Work Length: 19.21 Miles
#     Numbers: ['19.21']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180542.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180547.pdf
#   Match 1: Contract Project Length: 12.25 Miles
#     Numbers: ['12.25']
#   Match 2: Miles Work Length: 12.25 Miles
#     Numbers: ['12.25']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180548.pdf
#   Match 1: Contract Project Length: 3.85 Miles
#     Numbers: ['3.85']
#   Match 2: Miles Work Length: 3.76 Miles
#     Numbers: ['3.76']
#   Match 1 and Match 2 numbers are the same: False
# ----------------------------------------
# File: 180549.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180551.pdf
#   Match 1: Contract Project Length: 8.09 Miles
#     Numbers: ['8.09']
#   Match 2: Miles Work Length: 8.04 Miles
#     Numbers: ['8.04']
#   Match 1 and Match 2 numbers are the same: False
# ----------------------------------------
# File: 180555.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180556.pdf
#   Match 1: Contract Project Length: 9.58 Miles
#     Numbers: ['9.58']
#   Match 2: Miles Work Length: 9.50 Miles
#     Numbers: ['9.50']
#   Match 1 and Match 2 numbers are the same: False
# ----------------------------------------
# File: 180557.pdf
#   Match 1: Contract Project Length: 5.45 Miles
#     Numbers: ['5.45']
#   Match 2: Miles Work Length: 5.17 Miles
#     Numbers: ['5.17']
#   Match 1 and Match 2 numbers are the same: False
# ----------------------------------------
# File: 180560.pdf
#   Match 1: Contract Project Length: 8.85 Miles
#     Numbers: ['8.85']
#   Match 2: Miles Work Length: 8.85 Miles
#     Numbers: ['8.85']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180568.pdf
#   Match 1: Contract Project Length: 7.17 Miles
#     Numbers: ['7.17']
#   Match 2: Miles Work Length: 7.17 Miles
#     Numbers: ['7.17']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180569.pdf
#   Match 1: Contract Project Length: 6.19 Miles
#     Numbers: ['6.19']
#   Match 2: Miles Work Length: 6.19 Miles
#     Numbers: ['6.19']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180570.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180574.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180576.pdf
#   Match 1: Contract Project Length: 5.45 Miles
#     Numbers: ['5.45']
#   Match 2: Miles Work Length: 5.45 Miles
#     Numbers: ['5.45']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180577.pdf
#   Match 1: Contract Project Length: 12.11 MI
#     Numbers: ['12.11']
#   Match 2: Miles Work Length: 12.11 MI
#     Numbers: ['12.11']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180583.pdf
#   Match 1: Contract Project Length: 13.47 Miles
#     Numbers: ['13.47']
#   Match 2: Miles Work Length: 13.41 Miles
#     Numbers: ['13.41']
#   Match 1 and Match 2 numbers are the same: False
# ----------------------------------------
# File: 180584.pdf
#   Match 1: Contract Project Length: 7.32 Miles
#     Numbers: ['7.32']
#   Match 2: Miles Work Length: 7.32 Miles
#     Numbers: ['7.32']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180585.pdf
#   Match 1: Contract Project Length: 8.02 Miles
#     Numbers: ['8.02']
#   Match 2: Miles Work Length: 8.02 Miles
#     Numbers: ['8.02']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180589.pdf
#   Match 1: Contract Project Length: 11.45 MI
#     Numbers: ['11.45']
#   Match 2: Miles Work Length: 11.45 MI
#     Numbers: ['11.45']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180592.pdf
#   Match 1: Contract Project Length: 3.73 Miles
#     Numbers: ['3.73']
#   Match 2: Miles Work Length: 2.72 Miles
#     Numbers: ['2.72']
#   Match 1 and Match 2 numbers are the same: False
# ----------------------------------------
# File: 180600.pdf
#   Match 1: Contract Project Length: 11.44 MI
#     Numbers: ['11.44']
#   Match 2: Miles Work Length: 11.44 MI
#     Numbers: ['11.44']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180607.pdf
#   Match 1: Contract Project Length: 2.50 MI
#     Numbers: ['2.50']
#   Match 2: Miles Work Length: 2.50 MI
#     Numbers: ['2.50']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180609.pdf
#   Match 1: Contract Project Length: 11.23 Miles
#     Numbers: ['11.23']
#   Match 2: Miles Work Length: 11.15 Miles
#     Numbers: ['11.15']
#   Match 1 and Match 2 numbers are the same: False
# ----------------------------------------
# File: 180610.pdf
#   Match 1: Contract Project Length: 11.69 MI
#     Numbers: ['11.69']
#   Match 2: Miles Work Length: 11.69 MI
#     Numbers: ['11.69']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180611.pdf
#   Match 1: Contract Project Length: NA Miles
#     Numbers: []
#   Match 2: Miles Work Length: NA Miles
#     Numbers: []
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180621.pdf
#   Match 1: Contract Project Length: 13.06 MI
#     Numbers: ['13.06']
#   Match 2: Miles Work Length: 13.06 MI
#     Numbers: ['13.06']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 180622.pdf
#   Match 1: Contract Project Length: 24.61 Miles
#     Numbers: ['24.61']
#   Match 2: Miles Work Length: 24.58 Miles
#     Numbers: ['24.58']
#   Match 1 and Match 2 numbers are the same: False
# ----------------------------------------
# File: 184002.pdf
#   Match 1: Contract Project Length: 1.67 Miles
#     Numbers: ['1.67']
#   Match 2: Miles Work Length: 1.67 Miles
#     Numbers: ['1.67']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
# File: 187023.pdf
#   Match 1: Contract Project Length: 17.59 Miles
#     Numbers: ['17.59']
#   Match 2: Miles Work Length: 17.59 Miles
#     Numbers: ['17.59']
#   Match 1 and Match 2 numbers are the same: True
# ----------------------------------------
#
# Processed 202 files. 202 files had at least two 'length:' matches.
#
# DataFrame of extracted length numbers and comparisons:
#     project_number  num_matches  match_1  match_2  all_matches_same  \
# 0           170561            2  [10.15]  [10.15]              True
# 1           170626            2       []       []              True
# 2           170634            2  [13.93]  [13.93]              True
# 3           174015            2   [5.45]   [5.45]              True
# 4           174016            2   [1.22]   [1.22]              True
# ..             ...          ...      ...      ...               ...
# 197         180611            2       []       []              True
# 198         180621            2  [13.06]  [13.06]              True
# 199         180622            2  [24.61]  [24.58]             False
# 200         184002            2   [1.67]   [1.67]              True
# 201         187023            2  [17.59]  [17.59]              True
#
#      comparison_1_2  numbers_in_match_1  numbers_in_match_2
# 0              True                   1                   1
# 1              True                   0                   0
# 2              True                   1                   1
# 3              True                   1                   1
# 4              True                   1                   1
# ..              ...                 ...                 ...
# 197            True                   0                   0
# 198            True                   1                   1
# 199           False                   1                   1
# 200            True                   1                   1
# 201            True                   1                   1
#
# [202 rows x 8 columns]

# %% [markdown]
# We analyze whether Project Length and Work Length have different properties. We see that they are different; therefore, we should consider whether we will use project length or work length.

# %%
# Show all rows in pdf_df where 'all_matches_same' is False
pdf_df[pdf_df['all_matches_same'] == False]
# Out:
#     project_number  num_matches  match_1  match_2  all_matches_same  \
# 5           180003            2   [9.19]   [9.13]             False
# 30          180090            2   [8.85]   [8.76]             False
# 49          180139            2   [4.56]   [4.18]             False
# 82          180232            2   [1.19]   [1.20]             False
# 117         180385            2   [2.85]   [2.76]             False
# 150         180475            2  [18.97]  [18.92]             False
# 156         180490            2   [1.18]   [1.25]             False
# 162         180509            2  [12.47]  [12.31]             False
# 165         180520            2  [19.40]  [19.20]             False
# 167         180522            2  [16.98]  [12.27]             False
# 175         180548            2   [3.85]   [3.76]             False
# 177         180551            2   [8.09]   [8.04]             False
# 179         180556            2   [9.58]   [9.50]             False
# 180         180557            2   [5.45]   [5.17]             False
# 188         180583            2  [13.47]  [13.41]             False
# 192         180592            2   [3.73]   [2.72]             False
# 195         180609            2  [11.23]  [11.15]             False
# 199         180622            2  [24.61]  [24.58]             False
#
#      comparison_1_2  numbers_in_match_1  numbers_in_match_2
# 5             False                   1                   1
# 30            False                   1                   1
# 49            False                   1                   1
# 82            False                   1                   1
# 117           False                   1                   1
# 150           False                   1                   1
# 156           False                   1                   1
# 162           False                   1                   1
# 165           False                   1                   1
# 167           False                   1                   1
# 175           False                   1                   1
# 177           False                   1                   1
# 179           False                   1                   1
# 180           False                   1                   1
# 188           False                   1                   1
# 192           False                   1                   1
# 195           False                   1                   1
# 199           False                   1                   1

# %%
# Save the pdf_df DataFrame as a CSV file
pdf_df.to_csv("pdf_length_comparison.csv", index=False)
print("Saved pdf_df to pdf_length_comparison.csv")
# Out:
# Saved pdf_df to pdf_length_comparison.csv

# %% [markdown]
# We may be confused whether to use project length or work length, but given the definition is mileage: length of the project, we use project length.

# %%
# Extract numbers associated with 'Project Length: NA Miles' or 'Project Length: NA MI Miles' from each PDF
import os
import re
import PyPDF2
import pandas as pd

pdf_dir = r"C:\Users\clint\Desktop\RA Task\Downloads"
pdf_pattern = re.compile(r"^\d+\.pdf$")

project_length_results = []
pdf_files = [f for f in os.listdir(pdf_dir) if pdf_pattern.match(f)]

for filename in pdf_files:
    pdf_path = os.path.join(pdf_dir, filename)
    try:
        with open(pdf_path, "rb") as file:
            reader = PyPDF2.PdfReader(file)
            text = ""
            for page in reader.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text + " "
            
            # Improved regex to find 'Project Length: NA Miles' or 'Project Length: NA MI Miles'
            # This pattern handles:
            # - "Project Length: 7.21 Miles"
            # - "Project Length: 7.21 MI Miles"
            # - Various whitespace combinations
            matches = re.findall(r"Project Length:\s*([\d\.]+)\s*(?:MI\s+)?Miles", text, re.IGNORECASE)
            
            project_length_results.append({
                "filename": filename,
                "project_lengths": matches
            })
    except Exception as e:
        project_length_results.append({
            "filename": filename,
            "project_lengths": [],
            "error": str(e)
        })

# Create DataFrame
project_length_df = pd.DataFrame(project_length_results)
print("Project Lengths extracted from PDFs (handling both 'Miles' and 'MI Miles' formats):")
display(project_length_df)
# Out:
# Project Lengths extracted from PDFs (handling both 'Miles' and 'MI Miles' formats):
#        filename project_lengths
# 0    170561.pdf         [10.15]
# 1    170626.pdf              []
# 2    170634.pdf         [13.93]
# 3    174015.pdf          [5.45]
# 4    174016.pdf          [1.22]
# ..          ...             ...
# 206  180622.pdf         [24.61]
# 207  184002.pdf          [1.67]
# 208  187023.pdf         [17.59]
# 209  188000.pdf          [5.45]
# 210  188001.pdf         [13.93]
#
# [211 rows x 2 columns]

# %%
project_length_df.to_csv("project_length_extracted.csv", index=False)
print("Saved project_length_df to project_length_extracted.csv")
# Out:
# Saved project_length_df to project_length_extracted.csv

# %%
# Test the improved regex pattern with sample text containing both formats
import re

# Test strings with different formats
test_texts = [
    "Project Length: 7.21 Miles",
    "Project Length: 7.21 MI Miles", 
    "Project Length:    5.45   Miles",
    "Project Length:   3.22 MI    Miles",
    "project length: 10.15 mi miles",  # Test case-insensitive
    "Work Length: 2.50 Miles",  # Should not match
    "Project Length: 15.33 KM"   # Should not match
]

# The improved regex pattern
pattern = r"Project Length:\s*([\d\.]+)\s*(?:MI\s+)?Miles"

print("Testing improved regex pattern:")
print("Pattern:", pattern)
print("\nTest results:")
for text in test_texts:
    matches = re.findall(pattern, text, re.IGNORECASE)
    print(f"Text: '{text}' -> Matches: {matches}")

print("\nThe pattern successfully captures numbers from both 'Miles' and 'MI Miles' formats!")
# Out:
# Testing improved regex pattern:
# Pattern: Project Length:\s*([\d\.]+)\s*(?:MI\s+)?Miles
#
# Test results:
# Text: 'Project Length: 7.21 Miles' -> Matches: ['7.21']
# Text: 'Project Length: 7.21 MI Miles' -> Matches: ['7.21']
# Text: 'Project Length:    5.45   Miles' -> Matches: ['5.45']
# Text: 'Project Length:   3.22 MI    Miles' -> Matches: ['3.22']
# Text: 'project length: 10.15 mi miles' -> Matches: ['10.15']
# Text: 'Work Length: 2.50 Miles' -> Matches: []
# Text: 'Project Length: 15.33 KM' -> Matches: []
#
# The pattern successfully captures numbers from both 'Miles' and 'MI Miles' formats!

# %%
# Save the updated DataFrame
project_length_df.to_csv("project_length_extracted_improved.csv", index=False)
print("\nSaved improved project_length_df to project_length_extracted_improved.csv")
